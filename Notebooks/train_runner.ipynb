# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import os
import sys
import torch
from src.train import train_model,train_xray_model
from src.models import build_model
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

from src.dataloader import SkinDataset


from src.evaluate import evaluate

from src.transforms import train_transform, val_transform

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
train_model(
    model_name="resnet",
    batch_size=32,
    epochs=20,
    learning_rate=1e-3
)
# Out:
# Best model saved! Validation Loss: 1.4895
# Epoch [1/20] Train Loss: 1.7600 | Val Loss: 1.4895 | Accuracy: 0.4980 | Macro F1: 0.2838 | Weighted F1: 0.5485
# Best model saved! Validation Loss: 1.4228
# Epoch [2/20] Train Loss: 1.5341 | Val Loss: 1.4228 | Accuracy: 0.5173 | Macro F1: 0.3487 | Weighted F1: 0.5680
# Epoch [3/20] Train Loss: 1.5072 | Val Loss: 1.6530 | Accuracy: 0.5533 | Macro F1: 0.3591 | Weighted F1: 0.5926
# Best model saved! Validation Loss: 1.2660
# Epoch [4/20] Train Loss: 1.3743 | Val Loss: 1.2660 | Accuracy: 0.5366 | Macro F1: 0.3797 | Weighted F1: 0.5869
# Epoch [5/20] Train Loss: 1.2763 | Val Loss: 1.5473 | Accuracy: 0.5499 | Macro F1: 0.4182 | Weighted F1: 0.6007
# Best model saved! Validation Loss: 1.1868
# Epoch [6/20] Train Loss: 1.2658 | Val Loss: 1.1868 | Accuracy: 0.5659 | Macro F1: 0.4089 | Weighted F1: 0.6123
# Best model saved! Validation Loss: 1.1696
# ...

# %%
train_xray_model(model_name="efficientnet", batch_size=32, epochs=20, learning_rate=0.001)
