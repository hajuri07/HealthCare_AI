# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import os
import sys
import torch
from src.train import train_model,train_xray_model
from src.models import build_model
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

from src.dataloader import SkinDataset


from src.evaluate import evaluate

from src.transforms import train_transform, val_transform

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
train_model(
    model_name="efficientnet",
    batch_size=12,
    epochs=15,
    learning_rate=1e-3
)
# Out:
# Kamm dandha chalu hogaya bitwaa
# Epoch [1/15] - Train: 100%|██████████| 584/584 [00:56<00:00, 10.33it/s, loss=0.248]
# Best model saved! Validation Loss: 1.3359
# Epoch [1/15] Train Loss: 1.5961 | Val Loss: 1.3359 | Accuracy: 0.5117 | Macro F1: 0.3888 | Weighted F1: 0.5690
# Epoch [2/15] - Train: 100%|██████████| 584/584 [00:52<00:00, 11.05it/s, loss=0.319]
# Best model saved! Validation Loss: 1.2458
# Epoch [2/15] Train Loss: 1.3745 | Val Loss: 1.2458 | Accuracy: 0.4680 | Macro F1: 0.3218 | Weighted F1: 0.5244
# Epoch [3/15] - Train: 100%|██████████| 584/584 [00:52<00:00, 11.17it/s, loss=0.343]
# Epoch [3/15] Train Loss: 1.2568 | Val Loss: 1.3126 | Accuracy: 0.5215 | Macro F1: 0.3706 | Weighted F1: 0.5746
# Epoch [4/15] - Train: 100%|██████████| 584/584 [00:55<00:00, 10.51it/s, loss=1.51]
# Best model saved! Validation Loss: 1.2284
# Epoch [4/15] Train Loss: 1.1621 | Val Loss: 1.2284 | Accuracy: 0.5379 | Macro F1: 0.3748 | Weighted F1: 0.5971
# Epoch [5/15] - Train: 100%|██████████| 584/584 [01:00<00:00,  9.72it/s, loss=1.14]
# Best model saved! Validation Loss: 1.0375
# Epoch [5/15] Train Loss: 1.1839 | Val Loss: 1.0375 | Accuracy: 0.5646 | Macro F1: 0.4437 | Weighted F1: 0.6074
# Epoch [6/15] - Train: 100%|██████████| 584/584 [00:59<00:00,  9.84it/s, loss=1.47]
# Epoch [6/15] Train Loss: 1.1272 | Val Loss: 1.4382 | Accuracy: 0.4093 | Macro F1: 0.3379 | Weighted F1: 0.4471
# Epoch [7/15] - Train: 100%|██████████| 584/584 [00:53<00:00, 10.97it/s, loss=1.71]
# Best model saved! Validation Loss: 0.8595
# Epoch [7/15] Train Loss: 1.0337 | Val Loss: 0.8595 | Accuracy: 0.6762 | Macro F1: 0.5081 | Weighted F1: 0.7034
# Epoch [8/15] - Train: 100%|██████████| 584/584 [00:55<00:00, 10.51it/s, loss=0.295]
# Epoch [8/15] Train Loss: 1.0020 | Val Loss: 0.9490 | Accuracy: 0.6136 | Macro F1: 0.4904 | Weighted F1: 0.6502
# Epoch [9/15] - Train: 100%|██████████| 584/584 [00:45<00:00, 12.73it/s, loss=0.909]
# Epoch [9/15] Train Loss: 0.9282 | Val Loss: 0.9993 | Accuracy: 0.6155 | Macro F1: 0.4535 | Weighted F1: 0.6578
# Epoch [10/15] - Train: 100%|██████████| 584/584 [00:40<00:00, 14.32it/s, loss=1.53]
# Epoch [10/15] Train Loss: 0.8784 | Val Loss: 0.8696 | Accuracy: 0.6449 | Macro F1: 0.5157 | Weighted F1: 0.6776
# Epoch [11/15] - Train: 100%|██████████| 584/584 [00:55<00:00, 10.50it/s, loss=0.6]
# Best model saved! Validation Loss: 0.7675
# Epoch [11/15] Train Loss: 0.7713 | Val Loss: 0.7675 | Accuracy: 0.6789 | Macro F1: 0.5482 | Weighted F1: 0.7083
# Epoch [12/15] - Train: 100%|██████████| 584/584 [00:56<00:00, 10.40it/s, loss=2.24]
# Best model saved! Validation Loss: 0.7627
# Epoch [12/15] Train Loss: 0.6654 | Val Loss: 0.7627 | Accuracy: 0.6873 | Macro F1: 0.5555 | Weighted F1: 0.7156
# Epoch [13/15] - Train: 100%|██████████| 584/584 [00:54<00:00, 10.76it/s, loss=0.186]
# Best model saved! Validation Loss: 0.7298
# Epoch [13/15] Train Loss: 0.6124 | Val Loss: 0.7298 | Accuracy: 0.7115 | Macro F1: 0.5637 | Weighted F1: 0.7334
# Epoch [14/15] - Train: 100%|██████████| 584/584 [00:57<00:00, 10.24it/s, loss=0.913]
# Epoch [14/15] Train Loss: 0.5970 | Val Loss: 0.7351 | Accuracy: 0.6984 | Macro F1: 0.5760 | Weighted F1: 0.7253
# Epoch [15/15] - Train: 100%|██████████| 584/584 [00:56<00:00, 10.40it/s, loss=0.731]
# Best model saved! Validation Loss: 0.7200
# Epoch [15/15] Train Loss: 0.5807 | Val Loss: 0.7200 | Accuracy: 0.7023 | Macro F1: 0.5663 | Weighted F1: 0.7275
